# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Laptopdata

# %%
dk=pd.read_csv("laptop_data.csv")

# %%
dk.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
dk.tail()
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram              Memory  \
# 1298            Intel Core i7 6500U 2.5GHz   4GB           128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB           512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB  64GB Flash Storage
# ...

# %% [markdown]
# #### This type of function is to retrive perticular data from the table
# #### All type of conditional function in the tabkle are performent by this

# %%
dk[dk["Price"]<70000]
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 5              5    Acer            Notebook    15.6
# 7              7   Apple           Ultrabook    13.3
# 9              9    Acer           Ultrabook    14.0
# ...          ...     ...                 ...     ...
# 1297        1297    Asus            Notebook    15.6
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                ScreenResolution  \
# 1                                      1440x900
# 2                             Full HD 1920x1080
# 5                                      1366x768
# 7                                      1440x900
# 9                   IPS Panel Full HD 1920x1080
# ...

# %%
dk["Cpu"].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %% [markdown]
# # Bankdata

# %%
df=pd.read_csv("banklist.csv")

# %%
df.head()
# Out:
#                                   Bank Name          City  ST   CERT  \
# 0  Banks of Wisconsin d/b/a Bank of Kenosha       Kenosha  WI  35386
# 1                      Central Arizona Bank    Scottsdale  AZ  34527
# 2                              Sunrise Bank      Valdosta  GA  58185
# 3                     Pisgah Community Bank     Asheville  NC  58701
# 4                       Douglas County Bank  Douglasville  GA  21649
#
#    Acquiring Institution Closing Date Updated Date
# 0  North Shore Bank, FSB    31-May-13    31-May-13
# 1     Western State Bank    14-May-13    20-May-13
# 2           Synovus Bank    10-May-13    21-May-13
# 3     Capital Bank, N.A.    10-May-13    14-May-13
# 4    Hamilton State Bank    26-Apr-13    16-May-13

# %% [markdown]
# #### Info gives you all the information about the csv file

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %% [markdown]
# #### Use value_count for mainly series only

# %%
df["City"].value_counts()
# Out:
# City
# Chicago        14
# Atlanta         9
# Naples          5
# Phoenix         5
# Bradenton       4
#                ..
# Dawsonville     1
# McCaysville     1
# Batesville      1
# Lino Lakes      1
# Honolulu        1
# Name: count, Length: 396, dtype: int64

# %%
df.describe()
# Out:
#               CERT
# count    506.00000
# mean   31948.91502
# std    16367.55409
# min      151.00000
# 25%    21222.75000
# 50%    32176.00000
# 75%    35385.25000
# max    58701.00000

# %%
df[df["City"]=="Chicago"]
# Out:
#                                              Bank Name     City  ST   CERT  \
# 11                                       Covenant Bank  Chicago  IL  22476
# 27   Second Federal Savings and Loan Association of...  Chicago  IL  27986
# 52                                       New City Bank  Chicago  IL  57597
# 108                         First Chicago Bank & Trust  Chicago  IL  27935
# 143                       Community First Bank Chicago  Chicago  IL  57948
# 200                                          ShoreBank  Chicago  IL  15640
# 205                                    Ravenswood Bank  Chicago  IL  34231
# 259                          Lincoln Park Savings Bank  Chicago  IL  30600
# 260                                   New Century Bank  Chicago  IL  34821
# 261         Citizens Bank and Trust Company of Chicago  Chicago  IL  34658
# 262                                      Broadway Bank  Chicago  IL  22853
# ...

# %%
from io import StringIO, BytesIO

# %%
data=('col1,col2,col3\n'
           'x,y,1\n'
            'a,b,2\n'
            'c,d,3' )

# %%
type(data)
# Out:
# str

# %%
pd.read_csv(StringIO(data))
# Out:
#   col1 col2  col3
# 0    x    y     1
# 1    a    b     2
# 2    c    d     3
