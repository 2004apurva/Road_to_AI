# %% [markdown]
# # OpenCV

# %% [markdown]
# ##### Installing packages

# %%
pip install opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB 660.6 kB/s eta 0:00:59
#    ---------------------------------------- 0.1/38.8 MB 812.7 kB/s eta 0:00:48
#    ---------------------------------------- 0.1/38.8 MB 1.0 MB/s eta 0:00:38
#    ---------------------------------------- 0.2/38.8 MB 984.6 kB/s eta 0:00:40
#    ---------------------------------------- 0.2/38.8 MB 1.1 MB/s eta 0:00:35
#    ---------------------------------------- 0.3/38.8 MB 1.4 MB/s eta 0:00:29
#    ---------------------------------------- 0.5/38.8 MB 1.6 MB/s eta 0:00:25
#     --------------------------------------- 0.6/38.8 MB 1.7 MB/s eta 0:00:23
#     --------------------------------------- 0.7/38.8 MB 1.9 MB/s eta 0:00:20
#     --------------------------------------- 0.9/38.8 MB 2.0 MB/s eta 0:00:19
#    - -------------------------------------- 1.1/38.8 MB 2.2 MB/s eta 0:00:17
# ...

# %%
pip install opencv-contrib-python
# Out:
# ...
#    ---------------------------------------- 0.0/45.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/45.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/45.5 MB 653.6 kB/s eta 0:01:10
#    ---------------------------------------- 0.1/45.5 MB 787.7 kB/s eta 0:00:58
#    ---------------------------------------- 0.1/45.5 MB 853.3 kB/s eta 0:00:54
#    ---------------------------------------- 0.2/45.5 MB 1.1 MB/s eta 0:00:41
#    ---------------------------------------- 0.3/45.5 MB 1.1 MB/s eta 0:00:42
#    ---------------------------------------- 0.4/45.5 MB 1.4 MB/s eta 0:00:33
#    ---------------------------------------- 0.4/45.5 MB 1.3 MB/s eta 0:00:36
#    ---------------------------------------- 0.5/45.5 MB 1.4 MB/s eta 0:00:33
#     --------------------------------------- 0.6/45.5 MB 1.5 MB/s eta 0:00:31
#     --------------------------------------- 0.7/45.5 MB 1.5 MB/s eta 0:00:30
# ...

# %%
pip install caer
# Out:
# ...
#    ---------------------------------------- 0.0/809.5 kB ? eta -:--:--
#     -------------------------------------- 20.5/809.5 kB 640.0 kB/s eta 0:00:02
#    - ------------------------------------- 30.7/809.5 kB 435.7 kB/s eta 0:00:02
#    --- ----------------------------------- 81.9/809.5 kB 573.4 kB/s eta 0:00:02
#    ----- -------------------------------- 122.9/809.5 kB 599.1 kB/s eta 0:00:02
#    --------- ---------------------------- 204.8/809.5 kB 888.4 kB/s eta 0:00:01
#    ------------ ------------------------- 256.0/809.5 kB 923.9 kB/s eta 0:00:01
#    ---------------------- ----------------- 450.6/809.5 kB 1.3 MB/s eta 0:00:01
#    -------------------------- ------------- 532.5/809.5 kB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 768.0/809.5 kB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  809.0/809.5 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 809.5/809.5 kB 1.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Image Reading

# %%
# Importing Libaries
import numpy as np
import cv2

# %% [markdown]
# #### Reading and showing the image image

# %%
import cv2

# Read the image from the same directory
image = cv2.imread('./Photos/cat.jpg')  # replace 'image_name.jpg' with your actual image file name

# Check if the image was successfully loaded
if image is None:
    print("Error: Could not read the image.")
else:
    # Display the image
    cv2.imshow('Cat', image)


    # Wait for a key press and close the image window
    cv2.waitKey()
    cv2.destroyAllWindows()

# %%
import cv2 

# Loading an image using "imread" specifing the of the image

# Our file "Photo/cat.jpg" is now loadind in and stored in python

img = cv2.imread("./Photos/cat.jpg")

# To display our image we will use "imshow"

cv2.imshow("Cat",img)

# Waitkey is for time the image window will be open
# If you enter 0 / nothing it wait untill you press any key
cv2.waitKey()

# It will close the window after any key/ perticular key is pressed
cv2.destroyAllWindows()

# %% [markdown]
# #### How Image are stored

# %%
# ".shape" will show (height(pixels),width(pixels),number of channels)

img.shape
# Out:
# (427, 640, 3)

# %%
# more specefic nothing just showing what does ".shape" show

print("Height of the image:", img.shape[0],     "pixels")
print("Width of the image:",  img.shape[1]  ,  "pixels")
# Out:
# Height of the image: 427 pixels
# Width of the image: 640 pixels

# %% [markdown]
# #### Storing the edited image in different file/ format

# %%
cv2.imwrite("Output.jpg", img)
cv2.imwrite("Output.png", img)

# %% [markdown]
# ## Video Reading

# %% [markdown]
# ### WEBCAM

# %%
capture = cv2.VideoCapture(0)


while True:
    success , img =capture.read()

    cv2.imshow("Video", img)

    if cv2.waitKey(1) & 0xFF ==ord("q"):
        
        break
       

capture.release()
cv2.destroyAllWindows()

# %%
# Open a connection to the webcam (0 is the default camera)
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()

    if not ret:
        print("Error: Could not read frame.")
        break

    # Display the resulting frame
    cv2.imshow('Webcam', frame)

    # Press 'q' on the keyboard to exit the loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# When everything is done, release the capture
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### DOWNLOADED Video

# %%
video = cv2.VideoCapture("./Videos/kitten.mp4")

while True:
    success , img =video.read()
    
    cv2.imshow("Video", img)

    if cv2.waitKey(1) & 0xFF ==ord("q"):
        
        break


video.release()
cv2.destroyAllWindows()
